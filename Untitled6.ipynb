# %% [markdown]
# <a href="https://colab.research.google.com/github/haydarsenoll/Preprocessing-/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("tips")
df_copied = df.copy()

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
#sütun adlarını değiştirme

# %%
df.rename(columns = {"total_bill" : "Fiyat",
 "sex" : "Cinsiyet",
  "time" : "Zaman" ,
  "day" : "Gün" ,
  "size" : "boyut" ,
 "tip" : "bahşiş"},inplace =True)

# %%
df
# Out:
#      Fiyat  bahşiş Cinsiyet smoker   Gün   Zaman  boyut
# 0    16.99    1.01   Female     No   Sun  Dinner      2
# 1    10.34    1.66     Male     No   Sun  Dinner      3
# 2    21.01    3.50     Male     No   Sun  Dinner      3
# 3    23.68    3.31     Male     No   Sun  Dinner      2
# 4    24.59    3.61   Female     No   Sun  Dinner      4
# ..     ...     ...      ...    ...   ...     ...    ...
# 239  29.03    5.92     Male     No   Sat  Dinner      3
# 240  27.18    2.00   Female    Yes   Sat  Dinner      2
# 241  22.67    2.00     Male    Yes   Sat  Dinner      2
# 242  17.82    1.75     Male     No   Sat  Dinner      2
# 243  18.78    3.00   Female     No  Thur  Dinner      2
#
# [244 rows x 7 columns]

# %%
df.Gün.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df.Zaman.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
df['Cinsiyet'] = df.Cinsiyet.map({"Female": 0 ,"Male" : 1})

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df['Zaman'] = LE.fit_transform(df['Zaman'])

# %%
df.head(70)
# Out:
#     Fiyat  bahşiş Cinsiyet smoker  Gün  Zaman  boyut
# 0   16.99    1.01        0     No  Sun      0      2
# 1   10.34    1.66        1     No  Sun      0      3
# 2   21.01    3.50        1     No  Sun      0      3
# 3   23.68    3.31        1     No  Sun      0      2
# 4   24.59    3.61        0     No  Sun      0      4
# ..    ...     ...      ...    ...  ...    ...    ...
# 65  20.08    3.15        1     No  Sat      0      3
# 66  16.45    2.47        0     No  Sat      0      2
# 67   3.07    1.00        0    Yes  Sat      0      1
# 68  20.23    2.01        1     No  Sat      0      2
# 69  15.01    2.09        1    Yes  Sat      0      2
#
# [70 rows x 7 columns]

# %%
df['Zaman'].value_counts()
# Out:
# Zaman
# 0    176
# 1     68
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df['Gün']=LE.fit_transform(df['Gün'])

# %%
df
# Out:
#      Fiyat  bahşiş Cinsiyet smoker  Gün  Zaman  boyut
# 0    16.99    1.01        0     No    2      0      2
# 1    10.34    1.66        1     No    2      0      3
# 2    21.01    3.50        1     No    2      0      3
# 3    23.68    3.31        1     No    2      0      2
# 4    24.59    3.61        0     No    2      0      4
# ..     ...     ...      ...    ...  ...    ...    ...
# 239  29.03    5.92        1     No    1      0      3
# 240  27.18    2.00        0    Yes    1      0      2
# 241  22.67    2.00        1    Yes    1      0      2
# 242  17.82    1.75        1     No    1      0      2
# 243  18.78    3.00        0     No    3      0      2
#
# [244 rows x 7 columns]

# %%
df['Gün'].value_counts()
# Out:
# Gün
# 1    87
# 2    76
# 3    62
# 0    19
# Name: count, dtype: int64

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-2f6f6606aa2c> in <cell line: 1>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
df['smoker'] = df.smoker.map({"No" : 0 , "Yes" : 1})

# %%
df
# Out:
#      Fiyat  bahşiş Cinsiyet smoker  Gün  Zaman  boyut
# 0    16.99    1.01        0      0    2      0      2
# 1    10.34    1.66        1      0    2      0      3
# 2    21.01    3.50        1      0    2      0      3
# 3    23.68    3.31        1      0    2      0      2
# 4    24.59    3.61        0      0    2      0      4
# ..     ...     ...      ...    ...  ...    ...    ...
# 239  29.03    5.92        1      0    1      0      3
# 240  27.18    2.00        0      1    1      0      2
# 241  22.67    2.00        1      1    1      0      2
# 242  17.82    1.75        1      0    1      0      2
# 243  18.78    3.00        0      0    3      0      2
#
# [244 rows x 7 columns]

# %%
df.corr()
# Out:
#              Fiyat    bahşiş  Cinsiyet    smoker       Gün     Zaman     boyut
# Fiyat     1.000000  0.675734  0.144877  0.085721 -0.043550 -0.183118  0.598315
# bahşiş    0.675734  1.000000  0.088862  0.005929 -0.011548 -0.121629  0.489299
# Cinsiyet  0.144877  0.088862  1.000000  0.002816 -0.078292 -0.205231  0.086195
# smoker    0.085721  0.005929  0.002816  1.000000 -0.282721 -0.054921 -0.133178
# Gün      -0.043550 -0.011548 -0.078292 -0.282721  1.000000  0.638019  0.069510
# Zaman    -0.183118 -0.121629 -0.205231 -0.054921  0.638019  1.000000 -0.103411
# boyut     0.598315  0.489299  0.086195 -0.133178  0.069510 -0.103411  1.000000

# %%
df

# %%
from google.colab import files
uploaded = files.upload()
print(uploaded)
# Out:
#      <input type="file" id="files-92cd8bc1-a16a-423c-9f1c-78756982eff8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92cd8bc1-a16a-423c-9f1c-78756982eff8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
files.download('tips.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-1d7f25fa84f5> in <cell line: 1>()
# ----> 1 files.download('tips.csv')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     223   if not _os.path.exists(filename):
#     224     msg = 'Cannot find file: {}'.format(filename)
# --> 225     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     226
#     227   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: tips.csv
